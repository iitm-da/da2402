# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/iitm-da/da2402/blob/master/data%20collection/rss_feed_scraper.ipynb)

# %% [markdown]
# # RSS feed scraper
#
# Pull the NDTV top-stories RSS feed with `feedparser` and turn the entries into a JSON structure.

# %% [markdown]
# ## Setup
#
# Install the two libraries if you don't already have them (uncomment the line below).

# %%
# !pip install requests feedparser

# %%
import requests
import feedparser
import json

# %% [markdown]
# ## Fetch and parse the feed

# %%
url = "https://feeds.feedburner.com/ndtvnews-top-stories"
feed = feedparser.parse(url)

# %% [markdown]
# ## Inspect what came back

# %%
print(feed.keys())

# %%
print(feed['entries'][0])

# %% [markdown]
# ## Build a JSON structure from the entries

# %%
feed_data = {"articles": []}
for entry in feed["entries"]:
    article = {
        "title": entry.get('title', ''),
        "link": entry.get('link', ''),
        "description": entry.get('summary', ''),
        "detail": entry.content[0].get('value', '')
    }
    feed_data["articles"].append(article)

# %%
print(json.dumps(feed_data, indent=4))

# %% [markdown]
# ## Full raw first entry, pretty-printed

# %%
print(json.dumps(feed['entries'][0], indent=4))
